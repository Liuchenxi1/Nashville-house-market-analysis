# %%
import pandas as pd

# %%
people = pd.read_csv('C:/Users/6106057/nss-data-analytics/projects/go_to_themoon/data/popluation_standard_compare_2010_2020.csv')

# %%
people.head()
# Out:
#          GEOID  state_code state_abbr  state_name  2010_density  \
# 0  0400000US01           1         AL     Alabama     94.376646
# 1  0400000US02           2         AK      Alaska      1.244620
# 2  0400000US04           4         AZ     Arizona     56.270686
# 3  0400000US05           5         AR    Arkansas     56.037115
# 4  0400000US06           6         CA  California    239.145863
#
#    2010_diversity_index  2010_pop  2010_pop_hisp  2010_pop_white_non_hisp  \
# 0                    48   4779736         185602                  3204402
# 1                    56    710231          39249                   455320
# 2                    57   6392017        1895149                  3695647
# 3                    42   2915918         186050                  2173469
# 4                    68  37253956       14013719                 14956253
#
#    2010_pop_black_non_hisp  ...  prop_change_gq_inst_other  \
# 0                  1244437  ...                      45.77
# ...

# %%
people.state_abbr.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR'], dtype=object)

# %%
tn = people[people['state_abbr'] == 'TN']
tn.columns
# Out:
# Index(['GEOID', 'state_code', 'state_abbr', 'state_name', '2010_density',
#        '2010_diversity_index', '2010_pop', '2010_pop_hisp',
#        '2010_pop_white_non_hisp', '2010_pop_black_non_hisp',
#        ...
#        'prop_change_gq_inst_other', 'prop_change_gq_noninst',
#        'prop_change_gq_noninst_college', 'prop_change_gq_noninst_military',
#        'prop_change_gq_noninst_other', 'prop_change_hu',
#        'prop_change_hu_occupied', 'prop_change_hu_vacant',
#        'prop_change_land_area_sqmi', 'flag_prop_change_land_area'],
#       dtype='object', length=188)

# %%
tn.2010_diversity_index
# Out:
#   File "<ipython-input-33-66f833cf6192>", line 1
#     tn.2010_diversity_index
#            ^
# SyntaxError: invalid decimal literal
