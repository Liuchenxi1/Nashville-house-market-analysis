# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rental = pd.read_csv('C:/Users/6106057/nss-data-analytics/projects/go_to_themoon/data/RENTALS.csv')

# %%
rental.head()
# Out:
#    RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0    102001                       United States         0   1347.0     1352
# 1    394913                        New York, NY         1   2356.0     2366
# 2    753899  Los Angeles-Long Beach-Anaheim, CA         2   1719.0     1730
# 3    394463                         Chicago, IL         3   1374.0     1378
# 4    394514               Dallas-Fort Worth, TX         4   1125.0     1129
#
#    2014-03  2014-04  2014-05  2014-06  2014-07  ...  2021-01  2021-02  \
# 0   1358.0     1364     1369     1375     1380  ...     1727     1744
# 1   2376.0     2387     2397     2408     2418  ...     2592     2608
# 2   1740.0     1750     1761     1771     1782  ...     2347     2366
# 3   1381.0     1385     1388     1392     1395  ...     1583     1591
# 4   1132.0     1136     1139     1143     1147  ...     1480     1498
#
#    2021-03  2021-04  2021-05  2021-06  2021-07  2021-08  2021-09  2021-10
# ...

# %%
rental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 97 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionID    105 non-null    int64
#  1   RegionName  105 non-null    object
#  2   SizeRank    105 non-null    int64
#  3   2014-01     100 non-null    float64
#  4   2014-02     105 non-null    int64
#  5   2014-03     104 non-null    float64
#  6   2014-04     105 non-null    int64
#  7   2014-05     105 non-null    int64
#  8   2014-06     105 non-null    int64
#  9   2014-07     105 non-null    int64
#  10  2014-08     105 non-null    int64
#  11  2014-09     105 non-null    int64
#  12  2014-10     105 non-null    int64
#  13  2014-11     105 non-null    int64
#  14  2014-12     105 non-null    int64
#  15  2015-01     105 non-null    int64
#  16  2015-02     105 non-null    int64
#  17  2015-03     105 non-null    int64
#  18  2015-04     105 non-null    int64
# ...

# %%
rental = rental.drop(['RegionID','SizeRank'], axis =1)

# %%
rental.head()
# Out:
#                            RegionName  2014-01  2014-02  2014-03  2014-04  \
# 0                       United States   1347.0     1352   1358.0     1364
# 1                        New York, NY   2356.0     2366   2376.0     2387
# 2  Los Angeles-Long Beach-Anaheim, CA   1719.0     1730   1740.0     1750
# 3                         Chicago, IL   1374.0     1378   1381.0     1385
# 4               Dallas-Fort Worth, TX   1125.0     1129   1132.0     1136
#
#    2014-05  2014-06  2014-07  2014-08  2014-09  ...  2021-01  2021-02  \
# 0     1369     1375     1380     1386     1391  ...     1727     1744
# 1     2397     2408     2418     2429     2439  ...     2592     2608
# 2     1761     1771     1782     1792     1802  ...     2347     2366
# 3     1388     1392     1395     1399     1402  ...     1583     1591
# 4     1139     1143     1147     1150     1154  ...     1480     1498
#
#    2021-03  2021-04  2021-05  2021-06  2021-07  2021-08  2021-09  2021-10
# ...

# %%
rental.RegionName.unique()
# Out:
# array(['United States', 'New York, NY',
#        'Los Angeles-Long Beach-Anaheim, CA', 'Chicago, IL',
#        'Dallas-Fort Worth, TX', 'Philadelphia, PA', 'Houston, TX',
#        'Washington, DC', 'Miami-Fort Lauderdale, FL', 'Atlanta, GA',
#        'Boston, MA', 'San Francisco, CA', 'Detroit, MI', 'Riverside, CA',
#        'Phoenix, AZ', 'Seattle, WA', 'Minneapolis-St Paul, MN',
#        'San Diego, CA', 'St. Louis, MO', 'Tampa, FL', 'Baltimore, MD',
#        'Denver, CO', 'Pittsburgh, PA', 'Portland, OR', 'Charlotte, NC',
#        'Sacramento, CA', 'San Antonio, TX', 'Orlando, FL',
#        'Cincinnati, OH', 'Cleveland, OH', 'Kansas City, MO',
#        'Las Vegas, NV', 'Columbus, OH', 'Indianapolis, IN',
#        'San Jose, CA', 'Austin, TX', 'Virginia Beach, VA',
#        'Nashville, TN', 'Providence, RI', 'Milwaukee, WI',
#        'Jacksonville, FL', 'Memphis, TN', 'Oklahoma City, OK',
#        'Louisville-Jefferson County, KY', 'Hartford, CT', 'Richmond, VA',
# ...

# %%
threecities = rental[(rental['RegionName'] == 'Los Angeles-Long Beach-Anaheim, CA') | (rental['RegionName'] == 'Atlanta, GA') | (rental['RegionName'] == 'Nashville, TN')]

# %%
threecities.head()
# Out:
#                             RegionName  2014-01  2014-02  2014-03  2014-04  \
# 2   Los Angeles-Long Beach-Anaheim, CA   1719.0     1730   1740.0     1750
# 9                          Atlanta, GA   1078.0     1081   1085.0     1089
# 37                       Nashville, TN   1123.0     1131   1139.0     1147
#
#     2014-05  2014-06  2014-07  2014-08  2014-09  ...  2021-01  2021-02  \
# 2      1761     1771     1782     1792     1802  ...     2347     2366
# 9      1093     1097     1101     1105     1109  ...     1591     1617
# 37     1155     1163     1171     1178     1186  ...     1557     1576
#
#     2021-03  2021-04  2021-05  2021-06  2021-07  2021-08  2021-09  2021-10
# 2      2384     2402   2421.0     2440     2459     2480   2500.0   2521.0
# 9      1643     1668   1695.0     1721     1747     1775   1802.0   1830.0
# 37     1594     1613   1633.0     1652     1671     1692   1712.0   1733.0
#
# [3 rows x 95 columns]

# %%
cities_new = threecities.transpose()
cities_new
# Out:
#                                             2            9              37
# RegionName  Los Angeles-Long Beach-Anaheim, CA  Atlanta, GA  Nashville, TN
# 2014-01                                 1719.0       1078.0         1123.0
# 2014-02                                   1730         1081           1131
# 2014-03                                 1740.0       1085.0         1139.0
# 2014-04                                   1750         1089           1147
# ...                                        ...          ...            ...
# 2021-06                                   2440         1721           1652
# 2021-07                                   2459         1747           1671
# 2021-08                                   2480         1775           1692
# 2021-09                                 2500.0       1802.0         1712.0
# 2021-10                                 2521.0       1830.0         1733.0
#
# [95 rows x 3 columns]

# %%
cities_new.columns = cities_new.iloc[0]
cities_new
# Out:
# RegionName  Los Angeles-Long Beach-Anaheim, CA  Atlanta, GA  Nashville, TN
# RegionName  Los Angeles-Long Beach-Anaheim, CA  Atlanta, GA  Nashville, TN
# 2014-01                                 1719.0       1078.0         1123.0
# 2014-02                                   1730         1081           1131
# 2014-03                                 1740.0       1085.0         1139.0
# 2014-04                                   1750         1089           1147
# ...                                        ...          ...            ...
# 2021-06                                   2440         1721           1652
# 2021-07                                   2459         1747           1671
# 2021-08                                   2480         1775           1692
# 2021-09                                 2500.0       1802.0         1712.0
# 2021-10                                 2521.0       1830.0         1733.0
#
# [95 rows x 3 columns]

# %%
cities_new = cities_new.iloc[1: , :]
cities_new
# Out:
# RegionName Los Angeles-Long Beach-Anaheim, CA Atlanta, GA Nashville, TN
# 2014-01                                1719.0      1078.0        1123.0
# 2014-02                                  1730        1081          1131
# 2014-03                                1740.0      1085.0        1139.0
# 2014-04                                  1750        1089          1147
# 2014-05                                  1761        1093          1155
# ...                                       ...         ...           ...
# 2021-06                                  2440        1721          1652
# 2021-07                                  2459        1747          1671
# 2021-08                                  2480        1775          1692
# 2021-09                                2500.0      1802.0        1712.0
# 2021-10                                2521.0      1830.0        1733.0
#
# [94 rows x 3 columns]

# %%
cities_new.columns
# Out:
# Index(['Los Angeles-Long Beach-Anaheim, CA', 'Atlanta, GA', 'Nashville, TN'], dtype='object', name='RegionName')

# %%
cities_new = cities_new.rename(columns ={'index':'yearanddate'})

# %%
cities_new.columns
# Out:
# Index(['Los Angeles-Long Beach-Anaheim, CA', 'Atlanta, GA', 'Nashville, TN'], dtype='object', name='RegionName')

# %%
def fix_columns(column_list):
    new_cols =[]
    for col in column_list:
        col = col.lower()
        col = col.replace(', tn','')
        col = col.replace(', ca','')
        col = col.replace(', ga','')
        new_cols.append(col)
    
    return new_cols

# %%
cities_new.columns = fix_columns(cities_new.columns)

# %%
cities_new = cities_new.rename(columns = {'los angeles-long beach-anaheim':'la'})

# %%
cities_new.columns
# Out:
# Index(['la', 'atlanta', 'nashville'], dtype='object')

# %%
cities_new = cities_new.reset_index()
cities_new
# Out:
#       index      la atlanta nashville
# 0   2014-01  1719.0  1078.0    1123.0
# 1   2014-02    1730    1081      1131
# 2   2014-03  1740.0  1085.0    1139.0
# 3   2014-04    1750    1089      1147
# 4   2014-05    1761    1093      1155
# ..      ...     ...     ...       ...
# 89  2021-06    2440    1721      1652
# 90  2021-07    2459    1747      1671
# 91  2021-08    2480    1775      1692
# 92  2021-09  2500.0  1802.0    1712.0
# 93  2021-10  2521.0  1830.0    1733.0
#
# [94 rows x 4 columns]

# %%
cities_new.columns
# Out:
# Index(['index', 'la', 'atlanta', 'nashville'], dtype='object')

# %%
cities_new[['year','date']] = cities_new['index'].str.split("-", n=1, expand = True)

# %%
cities_new.head()
# Out:
#      index      la atlanta nashville  year date
# 0  2014-01  1719.0  1078.0    1123.0  2014   01
# 1  2014-02    1730    1081      1131  2014   02
# 2  2014-03  1740.0  1085.0    1139.0  2014   03
# 3  2014-04    1750    1089      1147  2014   04
# 4  2014-05    1761    1093      1155  2014   05

# %%
cities_new = cities_new.drop(['index','date'], axis =1)

# %%
cities_new[['la','atlanta','nashville','year']] = cities_new[['la','atlanta','nashville','year']].apply(pd.to_numeric)

# %%
rentalbyyear = cities_new.groupby(['year'])['la','atlanta','nashville'].median().reset_index()
print(rentalbyyear)
# Out:
#    year      la  atlanta  nashville
# 0  2014  1776.5   1099.0     1167.0
# 1  2015  1899.0   1153.5     1250.0
# 2  2016  2021.0   1222.0     1319.5
# 3  2017  2127.0   1290.0     1368.5
# 4  2018  2219.0   1365.5     1407.5
# 5  2019  2304.5   1444.0     1466.0
# 6  2020  2322.5   1500.5     1509.5
# 7  2021  2430.5   1708.0     1642.5
# <ipython-input-27-7965fb1a41f1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rentalbyyear = cities_new.groupby(['year'])['la','atlanta','nashville'].median().reset_index()

# %% [raw]
# rentalbyyear.to_csv('C:/Users/6106057/nss-data-analytics/projects/go_to_themoon/data/rentalbyyear.csv')

# %%
rentalbyyear = rentalbyyear.reset_index()

# %%
rentalbyyear.plot(x="year", y=["la", "atlanta", "nashville"], kind="bar", color = ('green', 'darkorange','yellow'))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
rentalbyyear
# Out:
#    index  year      la  atlanta  nashville
# 0      0  2014  1776.5   1099.0     1167.0
# 1      1  2015  1899.0   1153.5     1250.0
# 2      2  2016  2021.0   1222.0     1319.5
# 3      3  2017  2127.0   1290.0     1368.5
# 4      4  2018  2219.0   1365.5     1407.5
# 5      5  2019  2304.5   1444.0     1466.0
# 6      6  2020  2322.5   1500.5     1509.5
# 7      7  2021  2430.5   1708.0     1642.5

# %%
rentalbyyear = rentalbyyear.drop(['index'], axis =1)

# %%
plt.plot('year','la',data=rentalbyyear, color='skyblue',linewidth = 2)
plt.plot('year', 'atlanta', data=rentalbyyear, color= 'black',linewidth = 2)
plt.plot('year', 'nashville', data=rentalbyyear, color='yellow',linewidth = 2)
##plt.locator_params(axis='x', nbins=10)

plt.xlabel('year')

plt.legend()

plt.show()

# %%
ax = rentalbyyear.plot(x="year", y="la", kind="bar")
rentalbyyear.plot(x="year", y="atlanta", kind="bar", color="C2")
rentalbyyear.plot(x="year", y="nashville", kind="bar", color="C3")

plt.show()
